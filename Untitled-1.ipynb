# %%
import pandas as pd

# %%
excel = pd.ExcelFile(r"G:\Portfolio\Garments\Garments_Factory_MIS_Raw_Data.xlsx")

# %%
excel.sheet_names
# Out:
# ['01_Factory_Master',
#  '02_Line_Master',
#  '03_Buyer_Master',
#  '04_Style_Master',
#  '05_Order_Master',
#  '06_Production_Data',
#  '07_Cutting_Data',
#  '08_Quality_Data',
#  '09_Inventory_Item_Master',
#  '10_Inventory_Transaction',
#  '11_Shipment_Data',
#  '12_Employee_Master',
#  '13_Attendance_Data',
#  '14_Target_Planning',
#  '15_Supplier_Master',
#  '16_Purchase_Data']

# %%
df = pd.read_excel(excel,'02_Line_Master')

# %%
df.head(10)
# Out:
#   Line_ID Factory_ID Floor                   Line_Name        Line_Type  \
# 0     L01     FAC-01   F01         L01 - Standard Line         Standard
# 1     L02     FAC-01   F01         L02 - Standard Line         Standard
# 2     L03     FAC-01   F02            L03 - Basic Line            Basic
# 3     L04     FAC-01   F02            L04 - Basic Line            Basic
# 4     L05     FAC-01   F03  L05 - High Complexity Line  High Complexity
# 5     L06     FAC-01   F03         L06 - Standard Line         Standard
# 6     L07     FAC-01   F04         L07 - Standard Line         Standard
# 7     L08     FAC-01   F04            L08 - Basic Line            Basic
# 8     L09     FAC-02   F01         L09 - Standard Line         Standard
# 9     L10     FAC-02   F01            L10 - Basic Line            Basic
#
#    Standard_Manpower Supervisor_ID Line_Status
# 0                 35      EMP-0214      Active
# 1                 38      EMP-0145      Active
# ...

# %%
df.shape
# Out:
# (14, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Line_ID            14 non-null     str
#  1   Factory_ID         14 non-null     str
#  2   Floor              14 non-null     str
#  3   Line_Name          14 non-null     str
#  4   Line_Type          14 non-null     str
#  5   Standard_Manpower  14 non-null     int64
#  6   Supervisor_ID      14 non-null     str
#  7   Line_Status        14 non-null     str
# dtypes: int64(1), str(7)
# memory usage: 1.0 KB

# %%
df.isnull().sum()
# Out:
# Line_ID              0
# Factory_ID           0
# Floor                0
# Line_Name            0
# Line_Type            0
# Standard_Manpower    0
# Supervisor_ID        0
# Line_Status          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# dtype: bool

# %%
df = pd.read_excel(excel,'03_Buyer_Master')

# %%
df.shape
# Out:
# (13, 7)

# %%
df.head(10)
# Out:
#   Buyer_ID              Buyer_Name Buyer_Country   Buyer_Region  \
# 0  BYR-001  NorthStar Apparel Inc.           USA  North America
# 1  BYR-002  Bergman & Cole Fashion       Germany         Europe
# 2  BYR-003      Veltrix Sportswear           USA  North America
# 3  BYR-004     Comfort Line Basics            UK         Europe
# 4  BYR-005  Urban Trail Outfitters           USA  North America
# 5  BYR-006     Heritage Cotton Co.   Netherlands         Europe
# 6  BYR-007      Alpine Gear Europe        France         Europe
# 7  BYR-008       Solaris Kids Wear         Spain         Europe
# 8  BYR-009      Prime Casuals Ltd.            UK         Europe
# 9  BYR-010   Nordic Fjord Clothing         Italy         Europe
#
#        Buyer_Category Payment_Terms Active_Status
# 0        Retail Chain  L/C at Sight        Active
# 1    Department Store   L/C 60 Days        Active
# 2    Sportswear Brand   T/T 30 Days        Active
# 3      Value Retailer  L/C at Sight        Active
# ...

# %%
df['Buyer_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df = pd.read_excel(excel,'04_Style_Master')

# %%
df.head(10)
# Out:
#    Style_ID Buyer_ID  Style_Number Garment_Type Product_Category Fabric_Type  \
# 0  STY-0001  BYR-007  POL-2502-046   Polo Shirt             Knit      Jersey
# 1  STY-0002  BYR-006  LEG-2510-025     Leggings             Knit      Fleece
# 2  STY-0003  BYR-005  TRS-2508-082      Trouser            Woven       Denim
# 3  STY-0004  BYR-011  LEG-2503-069     Leggings             Knit       Denim
# 4  STY-0005  BYR-004  TSH-2501-041      T-Shirt             Knit      Jersey
# 5  STY-0006  BYR-005  HOD-2503-032       Hoodie             Knit       Twill
# 6  STY-0007  BYR-008  TNK-2502-097     Tank Top             Knit      Jersey
# 7  STY-0008  BYR-008  LEG-2509-033     Leggings             Knit       Denim
# 8  STY-0009  BYR-002  JOG-2505-056       Jogger             Knit       Denim
# 9  STY-0010  BYR-002  TNK-2511-039     Tank Top             Knit      Jersey
#
#             Fabric_Composition              Season  Gender Sleeve_Type  \
# ...

# %%
df.shape
# Out:
# (105, 14)

# %%
df.isnull().sum()
# Out:
# Style_ID                        0
# Buyer_ID                        0
# Style_Number                    0
# Garment_Type                    0
# Product_Category                0
# Fabric_Type                     0
# Fabric_Composition              0
# Season                          0
# Gender                          0
# Sleeve_Type                    30
# Neck_Type                      30
# Standard_SMV                    0
# Standard_Fabric_Consumption     0
# Standard_Accessories_Cost       0
# dtype: int64

# %%
df[df["Sleeve_Type"].isnull()][["Style_ID","Garment_Type", "Sleeve_Type", "Neck_Type"]]
# Out:
#      Style_ID Garment_Type Sleeve_Type Neck_Type
# 1    STY-0002     Leggings         NaN       NaN
# 2    STY-0003      Trouser         NaN       NaN
# 3    STY-0004     Leggings         NaN       NaN
# 7    STY-0008     Leggings         NaN       NaN
# 8    STY-0009       Jogger         NaN       NaN
# 13   STY-0014     Leggings         NaN       NaN
# 19   STY-0020     Leggings         NaN       NaN
# 21   STY-0022      Trouser         NaN       NaN
# 22   STY-0023      Trouser         NaN       NaN
# 24   STY-0025     Leggings         NaN       NaN
# 30   STY-0031      Trouser         NaN       NaN
# 31   STY-0032      Trouser         NaN       NaN
# 34   STY-0035     Leggings         NaN       NaN
# 43   STY-0044      Trouser         NaN       NaN
# 49   STY-0050       Jogger         NaN       NaN
# 51   STY-0052     Leggings         NaN       NaN
# 54   STY-0055       Jogger         NaN       NaN
# 57   STY-0058       Jogger         NaN       NaN
# ...

# %%
df["Style_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Style_ID                     105 non-null    str
#  1   Buyer_ID                     105 non-null    str
#  2   Style_Number                 105 non-null    str
#  3   Garment_Type                 105 non-null    str
#  4   Product_Category             105 non-null    str
#  5   Fabric_Type                  105 non-null    str
#  6   Fabric_Composition           105 non-null    str
#  7   Season                       105 non-null    str
#  8   Gender                       105 non-null    str
#  9   Sleeve_Type                  75 non-null     str
#  10  Neck_Type                    75 non-null     str
#  11  Standard_SMV                 105 non-null    float64
#  12  Standard_Fabric_Consumption  105 non-null    float64
# ...

# %%
df = pd.read_excel(excel,'05_Order_Master')

# %%
df.head(10)
# Out:
#         Order_ID Buyer_ID  Style_ID Order_Date    PO_Number  Order_Qty  \
# 0  ORD-2025-0001  BYR-007  STY-0013 2025-05-02  PO007050001      38500
# 1  ORD-2025-0002  BYR-003  STY-0098 2025-11-10  PO003110002      34000
# 2  ORD-2025-0003  BYR-003  STY-0070 2025-07-18  PO003070003      33000
# 3  ORD-2025-0004  BYR-008  STY-0008 2025-06-13  PO008060004      52000
# 4  ORD-2025-0005  BYR-001  STY-0031 2025-01-12  PO001010005       4500
# 5  ORD-2025-0006  BYR-006  STY-0071 2025-05-14  PO006050006      45000
# 6  ORD-2025-0007  BYR-013  STY-0078 2025-06-10  PO013060007      13500
# 7  ORD-2025-0008  BYR-011  STY-0087 2025-07-14  PO011070008      47500
# 8  ORD-2025-0009  BYR-013  STY-0012 2025-10-11  PO013100009      54500
# 9  ORD-2025-0010  BYR-009  STY-0024 2025-07-26  PO009070010      13500
#
#    Unit_Price_USD  Order_Value_USD Ex_Factory_Date Shipment_Date  Color_Count  \
# 0           17.76           683760      2025-07-03    2025-07-05            2
# ...

# %%
df["Order_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (420, 14)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 420 entries, 0 to 419
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order_ID         420 non-null    str
#  1   Buyer_ID         420 non-null    str
#  2   Style_ID         420 non-null    str
#  3   Order_Date       420 non-null    datetime64[us]
#  4   PO_Number        420 non-null    str
#  5   Order_Qty        420 non-null    int64
#  6   Unit_Price_USD   420 non-null    float64
#  7   Order_Value_USD  420 non-null    int64
#  8   Ex_Factory_Date  420 non-null    datetime64[us]
#  9   Shipment_Date    420 non-null    datetime64[us]
#  10  Color_Count      420 non-null    int64
#  11  Size_Range       420 non-null    str
#  12  Order_Status     420 non-null    str
#  13  Priority         420 non-null    str
# dtypes: datetime64[us](3), float64(1), int64(3), str(7)
# memory usage: 46.1 KB

# %%
df.isnull().sum()
# Out:
# Order_ID           0
# Buyer_ID           0
# Style_ID           0
# Order_Date         0
# PO_Number          0
# Order_Qty          0
# Unit_Price_USD     0
# Order_Value_USD    0
# Ex_Factory_Date    0
# Shipment_Date      0
# Color_Count        0
# Size_Range         0
# Order_Status       0
# Priority           0
# dtype: int64

# %%
df.describe()
# Out:
#                        Order_Date     Order_Qty  Unit_Price_USD  \
# count                         420    420.000000      420.000000
# mean   2025-07-07 23:46:17.142857  30382.142857        7.799000
# min           2025-01-01 00:00:00   3000.000000        2.020000
# 25%           2025-04-09 12:00:00  17000.000000        4.590000
# 50%           2025-07-15 00:00:00  28000.000000        7.060000
# 75%           2025-10-06 06:00:00  45000.000000        9.755000
# max           2025-12-28 00:00:00  60500.000000       20.970000
# std                           NaN  16438.895032        4.222147
#
#        Order_Value_USD      Ex_Factory_Date               Shipment_Date  \
# count     4.200000e+02                  420                         420
# mean      2.377338e+05  2025-10-02 01:36:00  2025-10-04 20:20:34.285714
# min       1.255500e+04  2025-03-11 00:00:00         2025-03-14 00:00:00
# 25%       9.021375e+04  2025-07-06 00:00:00         2025-07-09 00:00:00
# ...

# %%
df["Ex_Factory_Date"].dtype
# Out:
# dtype('<M8[us]')
